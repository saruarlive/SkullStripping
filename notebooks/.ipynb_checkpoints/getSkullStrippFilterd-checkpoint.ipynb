# %%
import os
#import shutil
import tempfile
import sys

import matplotlib.pyplot as plt
import numpy as np
import torch
import glob

import monai
import nibabel as nib
from monai.apps import DecathlonDataset
from monai.config import print_config
#from monai.data import DataLoader
from monai.data import CacheDataset, PersistentDataset, SmartCacheDataset, create_test_image_3d
from monai.losses import DiceLoss
from monai.metrics import DiceMetric
from monai.metrics import compute_meandice
from monai.networks.nets import UNet
from monai.networks.layers import Norm
#from monai.utils.misc import first
from monai.transforms import (
    AsChannelFirstd,
    AddChanneld,
    CenterSpatialCropd,
    Compose,
    LoadNiftid,
    MapTransform,
    NormalizeIntensityd,
    Resized,
    Orientationd,
    RandFlipd,
    RandScaleIntensityd,
    RandShiftIntensityd,
    RandSpatialCropd,
    Spacingd,
    RandRotated,
    ResizeWithPadOrCropd,
    ToTensord,
)
from monai.utils import set_determinism

from fastai.vision.all import *
from pathlib import Path
import pandas as pd
from fastai.data.all import *
from fastai.torch_basics import *
from tqdm import tqdm_notebook as tqdm
import shutil

print_config()
# Out:
# MONAI version: 0.3.0
# Python version: 3.7.7 (default, Mar 26 2020, 15:48:22)  [GCC 7.3.0]
# OS version: Linux (4.15.0-121-generic)
# Numpy version: 1.19.1
# Pytorch version: 1.6.0
# MONAI flags: HAS_EXT = False, USE_COMPILED = False
#
# Optional dependencies:
# Pytorch Ignite version: 0.4.2
# Nibabel version: 3.1.1
# scikit-image version: 0.17.2
# Pillow version: 7.0.0
# Tensorboard version: 2.3.0
# gdown version: 3.12.2
# TorchVision version: 0.7.0
# ITK version: 5.1.0
# tqdm version: 4.48.2
#
# For details about installing the optional dependencies, please visit:
#     https://docs.monai.io/en/latest/installation.html#installing-the-recommended-dependencies

# %%
from fastai.vision.all import *
from fastai.data.all import *
from fastai.torch_basics import *

from fastai.vision.all import *

from torch import nn
#import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from torchvision import datasets, transforms
import math
import torch
import os

# %%
set_determinism(seed=4096)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-8ef6850d8e1f> in <module>
# ----> 1 set_determinism(seed=4096)
#
# NameError: name 'set_determinism' is not defined

# %%
rootdir= os.getcwd()
dfTrain = pd.read_csv(f'{rootdir}/dfTrainVal.csv')
dfVal = pd.read_csv(f'{rootdir}/dfValSel.csv')
dfTest = pd.read_csv(f'{rootdir}/dfTestSel.csv')

# %%
dfTrain['usage'].unique()
# Out:
# array(['train', 'val'], dtype=object)

# %%
# dfTrain = dfTrainVal.loc[dfTrainVal['usage'] == 'train']
# dfTrain['usage'].unique(), dfTrain['usage'].count()  
dfTrain = dfTrain.loc[dfTrain['usage'] == 'train']

# %%
# dfVal = dfTrainVal.loc[dfTrainVal['usage'] == 'val']
# dfVal['usage'].unique(), dfVal['usage'].count()

# %%
dfTrain['usage'].count(), dfVal['usage'].count(), dfTest['usage'].count()
# Out:
# (2132, 658, 927)

# %%
train_files= [{'image':impath, 'label': lblpath} for impath, lblpath in zip(dfTrain['path_bias'], dfTrain['brain_mask_bias_nn'])]
val_files= [{'image':impath, 'label': lblpath} for impath, lblpath in zip(dfVal['path_bias'], dfVal['brain_mask_bias_nn'])]
test_files= [{'image':impath, 'label': lblpath} for impath, lblpath in zip(dfTest['path_bias'], dfTest['brain_mask_bias_nn'])]

# %%
#train_files, val_files = train_files[:10], val_files[:10]

# %% [markdown]
# ### Setting up validation/testing transform

# %%
train_transform = Compose(
    [
        # load 4 Nifti images and stack them together
        LoadNiftid(keys=["image", "label"]),
        AddChanneld(keys=['image','label']),
        #ConvertbinaryMaskd(keys="label"),
        Orientationd(keys=["image", "label"], axcodes="RAS"),
#        Spacingd(keys=["image", "label"], pixdim=(1.5, 1.5, 2.0), mode=("bilinear", "nearest")),
        Resized(keys=["image", "label"], spatial_size = (128, 128, 64), mode=("trilinear", "nearest")),
#        ResizeWithPadOrCropd(keys=["image", "label"], spatial_size = (128, 128, 64), mode=('edge')),
##         #RandSpatialCropd(keys=["image", "label"], roi_size=[160, 160, 92], random_size=False),
        RandRotated(keys = ['image', 'label'], range_x = [-10, 10], prob = 0.5, mode=("bilinear", "nearest")),
# #         RandFlipd(keys=["image", "label"], prob=0.5, spatial_axis=0),
        NormalizeIntensityd(keys="image", nonzero=True, channel_wise=False),
        RandScaleIntensityd(keys="image", factors=0.1, prob=0.5),
# #         RandShiftIntensityd(keys="image", offsets=0.1, prob=0.5),
        ToTensord(keys=["image", "label"]),
    ]
)
val_transform = Compose(
    [     
         LoadNiftid(keys=["image", "label"]),
         AddChanneld(keys=['image','label']),
         #ConvertbinaryMaskd(keys="label"),
         Orientationd(keys=["image", "label"], axcodes="RAS"),
         #Spacingd(keys=["image", "label"], pixdim=(1.5, 1.5, 2.0), mode=("bilinear", "nearest")),
         #CenterSpatialCropd(keys=["image", "label"], roi_size=[160, 160, 92]),
         #ResizeWithPadOrCropd(keys=["image", "label"], spatial_size = (128, 128, 64), mode=('edge')),
         Resized(keys=["image", "label"], spatial_size = (128, 128, 64), mode=("trilinear", "nearest")),
         NormalizeIntensityd(keys="image", nonzero=True, channel_wise=False),
         ToTensord(keys=["image", "label"]),
    ]
)

# %%
from CacheDatasetEx import myCacheDataset
from CacheDatasetEx import maiDataset

# %%
#train_dsM = monai.data.Dataset(data=train_files, transform=train_transform)
#train_ds = maiDataset(data=train_files, transform=train_transform)
train_ds = CacheDataset(data=train_files, transform=train_transform, cache_rate=1.0, num_workers=0)
#train_ds = mySmartCacheDataset(data=train_files, transform=train_transform, cache_num=100, replace_rate=0.2)

# train_ds = monai.data.Dataset(data=train_files, transform=train_transforms)
# use batch_size=2 to load images and use RandCropByPosNegLabeld
# to generate 2 x 4 images for network training
#train_loader = DataLoader(train_ds, batch_size=2, shuffle=True, num_workers=4)
#train_loader = monai.data.DataLoader(train_ds, batch_size=16, shuffle=True, num_workers=1)
# Out:
# ...
# Load and cache transformed data: 100%|██████████| 2132/2132 [14:35<00:00,  2.43it/s]

# %%
val_ds = CacheDataset(data=val_files, transform=val_transform, cache_rate=1.0, num_workers=0)
#val_loader = monai.data.DataLoader(val_ds, batch_size=1, num_workers=1, shuffle=False)
# Out:
# Load and cache transformed data: 100%|██████████| 658/658 [04:43<00:00,  2.32it/s]

# %%
val_ds[0][0].unique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-71689e4be8ca> in <module>
# ----> 1 val_ds[0][0].unique()
#
# KeyError: 0

# %%
xx = next(iter(train_loader))
xx['image'].unique(), xx['label'].shape, xx['image'].dtype, xx['label'].dtype, xx['label'].unique()
#xx[0].unique(), xx[1].shape, xx[0].dtype, xx[1].unique()

# %%
import fastai
from fastai.data.load import DataLoader as faiDataLoader

# %%
train_loaderT= faiDataLoader(train_ds, batch_size=16, shuffle=True, num_workers=1)  ###pin_memory=torch.cuda.is_available()
val_loaderT= faiDataLoader(val_ds, batch_size=16, shuffle=False, num_workers=1)     ###pin_memory=torch.cuda.is_available()
xx = next(iter(val_loaderT))
xx[0].unique(), xx[1].shape, xx[0].dtype, xx[1].dtype, xx[1].unique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-63-84310a01dc74> in <module>
#       2 val_loaderT= faiDataLoader(val_ds, batch_size=16, shuffle=False, num_workers=1)     ###pin_memory=torch.cuda.is_available()
#       3 xx = next(iter(val_loaderT))
# ----> 4 xx[0].unique(), xx[1].shape, xx[0].dtype, xx[1].dtype, xx[1].unique()
#
# KeyError: 0

# %% [markdown]
# ### Check data shape show

# %%
# pick one image from DecathlonDataset to visualize and check the 4 channels
def showImageshapes(val_ds, slice_nr = 30, nsubs= 2):
    
    image, label = (0,1) if isinstance(val_ds[0], tuple) else (list(val_ds[0].keys())[0],list(val_ds[0].keys())[1])
    nclass = val_ds[0][label].shape[0]
    nchannels = val_ds[0][image].shape[0]
    
    subs = torch.randint(0, len(val_ds), (nsubs,)) 
    
    for isub in subs:
        
        print(f"image shape: {val_ds[isub][image].shape}")
        plt.figure("image", (24, 6))
        for i in range(nchannels):
            plt.subplot(1, nchannels, i + 1)
            plt.title(f"image channel {i}")
            plt.imshow(val_ds[isub][image][i, :, :, slice_nr].detach().cpu(), cmap="gray")
        plt.show()
        # also visualize the 3 channels label corresponding to this image
        print(f"label shape: {val_ds[isub][label].shape}")
        plt.figure("label", (18, 6))
        for i in range(nclass):
            plt.subplot(1, nclass, i + 1)
            plt.title(f"label channel {i}")
            plt.imshow(val_ds[isub][label][i, :, :, slice_nr].detach().cpu())
        plt.show()
    
    
image = 0
label = 1
slice_nr = 27
nsubs = 3
showImageshapes(val_ds, slice_nr, nsubs)
# Out:
# image shape: torch.Size([1, 128, 128, 64])
# label shape: torch.Size([1, 128, 128, 64])
# image shape: torch.Size([1, 128, 128, 64])
# label shape: torch.Size([1, 128, 128, 64])
# image shape: torch.Size([1, 128, 128, 64])
# label shape: torch.Size([1, 128, 128, 64])

# %% [markdown]
# ### Showing batches

# %%
# pick one image from DecathlonDataset to visualize and check the 4 channels
def show_batch(train_dl, slice_nr = 30, nsubs = 2):
    
    fdl = next(iter(train_dl))
    #xx[0].unique(), xx[1].shape, xx[0].dtype, xx[1].dtype
    image, label = (0,1) if isinstance(fdl, list) else (list(fdl.keys())[0],list(fdl.keys())[1])
    nclass = fdl[label].shape[1]
    nchannels = fdl[image].shape[1]
    
    nsubs = nsubs if len(fdl[image])>nsubs else len(fdl[image])
    subs = torch.randint(0, len(fdl), (nsubs,)) 
      
    for isub in subs:
        
        print(f"image shape: {fdl[image].shape}")
        plt.figure("image", (24, 6))
        for i in range(nchannels):
            plt.subplot(1, nchannels, i + 1)
            plt.title(f"image channel {i}")
            plt.imshow(fdl[image][isub][i, :, :, slice_nr].detach().cpu(), cmap="gray")
        plt.show()
        # also visualize the 3 channels label corresponding to this image
        print(f"label shape: {fdl[label].shape}")
        plt.figure("label", (18, 6))
        for i in range(nclass):
            plt.subplot(1, nclass, i + 1)
            plt.title(f"label channel {i}")
            plt.imshow(fdl[label][isub][i, :, :, slice_nr].detach().cpu())
        plt.show()
    
    
image = 0
label = 1
slice_nr = 30
nsubs = 10
show_batch(train_loader, slice_nr, nsubs = nsubs)
# Out:
# image shape: torch.Size([16, 1, 128, 128, 64])
# label shape: torch.Size([16, 1, 128, 128, 64])
# image shape: torch.Size([16, 1, 128, 128, 64])
# label shape: torch.Size([16, 1, 128, 128, 64])
# image shape: torch.Size([16, 1, 128, 128, 64])
# label shape: torch.Size([16, 1, 128, 128, 64])
# image shape: torch.Size([16, 1, 128, 128, 64])
# label shape: torch.Size([16, 1, 128, 128, 64])
# image shape: torch.Size([16, 1, 128, 128, 64])
# label shape: torch.Size([16, 1, 128, 128, 64])
# image shape: torch.Size([16, 1, 128, 128, 64])
# label shape: torch.Size([16, 1, 128, 128, 64])
# image shape: torch.Size([16, 1, 128, 128, 64])
# label shape: torch.Size([16, 1, 128, 128, 64])
# image shape: torch.Size([16, 1, 128, 128, 64])
# label shape: torch.Size([16, 1, 128, 128, 64])
# image shape: torch.Size([16, 1, 128, 128, 64])
# label shape: torch.Size([16, 1, 128, 128, 64])
# image shape: torch.Size([16, 1, 128, 128, 64])
# label shape: torch.Size([16, 1, 128, 128, 64])

# %% [markdown]
# ### Defining a model

# %%
# # standard PyTorch program style: create UNet, DiceLoss and Adam optimizer
device = torch.device("cuda:0")
model = UNet(
    dimensions=3,
    in_channels=1,
    out_channels=2,
    channels=(16, 32, 64, 128, 256),
    strides=(2, 2, 2, 2),
    num_res_units=2,
    norm=Norm.BATCH,
    dropout=0.5,
    #num_res_units=16
).to(device)
#loss_function = DiceLoss(to_onehot_y=False, sigmoid=True, squared_pred=True)
loss_function = DiceLoss(to_onehot_y=True, softmax=True) #### Spleen example
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4, weight_decay=1e-5, amsgrad=True)

# %% [markdown]
# ### Custom dice

# %%
class DiceEx(Dice):
    
    #def __init__(self, axis=1): self.axis = axis
        
    def reset(self): self.metricX= 0.0
    
    def accumulate(self, learn):
      
        #dice_metric = DiceMetric(include_background=True, sigmoid=True, to_onehot_y=True, reduction="mean")
        metric_sum =  metric_sum_wt  = 0.0
        metric_count  = metric_count_wt  = 0

        pred=learn.pred
        targ = learn.y
        #targ=targ.unsqueeze(dim=1)

#         value1 = dice_metric(y_pred=pred, y=targ)    
#         not_nans = dice_metric.not_nans.item()
#         metric_count += not_nans
#         metric_sum += value1.item() * not_nans 
#         self.metricX = metric_sum
        
        value1=compute_meandice(y_pred=pred, y=targ, include_background=False, to_onehot_y=True, mutually_exclusive=True)
   
        self.metricX = value1.mean().item()
                
  
        ###targA[:,0,:,:]=np.where(targ==1,1,0)
        ##targA[:,1,:,:]=np.where(targ==1,1,0)
 
    @property
    def value(self): return self.metricX

# %% [markdown]
# ### Another approach of fastai

# %%
# class faiTransform(Transform):
#     def __init__(self, files, is_valid=False):
#         self.files,self.is_valid = files,is_valid
        
#     def encodes(self, i):
#         file1 = self.files[i]
#         trstatus = torch.tensor(0.) if self.is_valid else torch.tensor(1.)   
#         image,label = file1[0], file1[1]  
#         return (image, label)
    
class faiTransform(Transform):
    def __init__(self, files, is_valid=False):
        self.files,self.is_valid = files,is_valid
        #self.imagekey, self.labelkey=list(self.files[0].keys())[0], list(self.files[0].keys())[1]
        self.imagekey, self.labelkey = (0,1) if isinstance(val_ds[0], tuple) else (list(val_ds[0].keys())[0],list(val_ds[0].keys())[1])

    def encodes(self, i):
        file1 = self.files[i]
        #trstatus = torch.tensor(0.) if self.is_valid else torch.tensor(1.)   
        image,label = file1[self.imagekey], file1[self.labelkey]  
        return image, label
    #def __len__(self): return len(self.files)
    
# class faiTransform(Transform):
    
#     def __init__(self, files, is_valid=False):
#         self.files,self.is_valid = files,is_valid
#         self.imagekey, self.labelkey=list(self.files[0].keys())[0], list(self.files[0].keys())[1]

#     def encodes(self, i):
#         file1 = self.files[i]
#         #trstatus = torch.tensor(0.) if self.is_valid else torch.tensor(1.)   
#         image = file1[self.imagekey]  
#         return image
    
#     def encodes(self, i):
#         file1 = self.files[i]
#         #trstatus = torch.tensor(0.) if self.is_valid else torch.tensor(1.)   
#         label = file1[self.labelkey]  
#         return label

# %%
train_tl= TfmdLists(range(len(train_ds)), faiTransform(train_ds))
valid_tl= TfmdLists(range(len(val_ds)), faiTransform(val_ds, is_valid=True))

# %%
dls = DataLoaders.from_dsets(train_tl, valid_tl, bs=16, num_workers=16)
dls = dls.cuda()

# %%
learn = Learner(dls, model, loss_func=loss_function, opt_func=Adam, metrics=DiceEx(axis=1))
learn.freeze()

# %%
lr_min,lr_steep = learn.lr_find()
lr_min,lr_steep
# Out:
# (0.33113112449646, 0.019054606556892395)

# %%
learn.unfreeze()
learn.fine_tune(100, freeze_epochs=30)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>dice_ex</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.023633</td>
#       <td>0.021087</td>
#       <td>0.976463</td>
#       <td>01:31</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.023246</td>
#       <td>0.020483</td>
#       <td>0.977414</td>
#       <td>01:32</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.022064</td>
#       <td>0.019896</td>
#       <td>0.977804</td>
#       <td>01:32</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.022017</td>
#       <td>0.019490</td>
#       <td>0.978326</td>
#       <td>01:32</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.021534</td>
#       <td>0.019333</td>
#       <td>0.978904</td>
#       <td>01:32</td>
#     </tr>
#     <tr>
#       <td>5</td>
# ...

# %%
#### Saving the model

# %%
learn.unfreeze()
fname = f'{os.getcwd()}/BratsSkullStripJustTest.pkl'
learn.export(fname=fname, pickle_protocol=2)

# %%
os.getcwd()
# Out:
# '/home/saruarlive/MyProjects/skullStripping3D'

# %% [markdown]
# ### Combining training, and validation dataloaders to feed into fastai2's learner

# %%
##loss_func=CrossEntropyLossFlat(axis=1), metrics=Dice(axis=1)
dlss = DataLoaders(train_loaderT, val_loaderT)##.cuda()
learn = Learner(dlss, model, loss_func=loss_function, opt_func=Adam, metrics=DiceEx(axis=1), cbs=CudaCallback)##.to_fp16()   
#learn = Learner(dlss, model, loss_func=CrossEntropyLossFlat(axis=1), opt_func=Adam, metrics=Dice(axis=1), cbs=CudaCallback)#.to_fp16()

# %% [markdown]
# ### Learning rate finder

# %%
learn.unfreeze()
lr_min,lr_steep = learn.lr_find()
lr_min,lr_steep
# Out:
# (0.33113112449646, 0.019054606556892395)

# %% [markdown]
# ### Fine tuning

# %%
learn.unfreeze()
learn.fine_tune(50, freeze_epochs=15)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>dice_ex</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.330740</td>
#       <td>0.278682</td>
#       <td>0.923541</td>
#       <td>02:32</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.188632</td>
#       <td>0.122600</td>
#       <td>0.955088</td>
#       <td>02:35</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.099306</td>
#       <td>0.059657</td>
#       <td>0.966404</td>
#       <td>02:45</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.054221</td>
#       <td>0.039370</td>
#       <td>0.967335</td>
#       <td>03:01</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.035596</td>
#       <td>0.027165</td>
#       <td>0.973516</td>
#       <td>03:04</td>
#     </tr>
#     <tr>
#       <td>5</td>
# ...

# %%
def showSeginference(tlearn, test_files, val_transform, withMask = True, nsubs = 2 , slice_nr = 25):
    test_ds = []
    test_loader = []
    if withMask:
        test_ds = maiDataset(data=test_files, transform=val_transform)
        #test_ds = monai.data.Dataset(data=test_files, transform=val_transform)
        test_loader= faiDataLoader(test_ds, batch_size=1, shuffle=False, num_workers=0)
        
    else:
        fakeim, fakeseg = create_test_image_3d(256, 256, 256)
        n = nib.Nifti1Image(fakeseg, np.eye(4))
        nib.save(n, os.path.join(os.getcwd(), "segfake1.nii.gz"))
        #nib.load(os.path.join(os.getcwd(), f"segfake1.nii.gz"))
        labelpath = len(test_files)*[os.path.join(os.getcwd(), "segfake1.nii.gz")]
        
        test_files = [{'image':image, 'label': label} for image, label in zip(test_files, labelpath)]
        #print(test_files)
        #test_ds = myCacheDataset(data=test_files, transform=val_transform, cache_rate=1.0, num_workers=0)
        test_ds = maiDataset(data=test_files, transform=val_transform)
        #test_ds = monai.data.Dataset(data=test_files, transform=val_transform)
        test_loader= faiDataLoader(test_ds, batch_size=5, shuffle=False, num_workers=0)


        
    image, label = (0,1) if isinstance(test_ds[0], tuple) else (list(test_ds[0].keys())[0],list(test_ds[0].keys())[1])
    subs = torch.randint(0, len(test_ds), (nsubs,))
    nclass = test_ds[0][label].shape[0]
    nchannels = test_ds[0][image].shape[0]
    
    pred, targ = tlearn.get_preds(dl=test_loader)
    
    for iSub in subs:
        
    
        with torch.no_grad():
            # select one image to evaluate and visualize the model output
            #test_input = test_ds[val_sub][image]
            #val_output = model(val_input)
            
            
            val_output=pred[iSub, :, :,:, :]
            plt.figure("image", (24, 6))
            ####Input image
            plt.subplot(1, 3, 1)
            plt.title(f"image channel-single")
            plt.imshow(test_ds[iSub][image][0, :, :, slice_nr], cmap="gray")
            
            #### Input Mask
            
            plt.subplot(1, 3, 2)
            plt.title(f"label channel-single")
            plt.imshow(test_ds[iSub][label][0, :, :, slice_nr], cmap="gray")
            
            plt.subplot(1, 3, 3)
            plt.title(f"Predicted skull stripped output")
            plt.imshow((val_output[0, :, :, slice_nr].sigmoid() <= 0.5).float().detach().cpu(), cmap="gray")
            
            plt.show()
# Out:
# Load and cache transformed data:   0%|          | 0/10 [04:43<?, ?it/s]

# %%
# np.random.shuffle(val_files)
slice_nr = 30
val_sub=4
image = 0
label = 1
outclasses = 1
nsubs = 6

# tf = []
# for i in range(5):
#     tf.extend([test_files[i]['image']])
    
showSeginference(learn, test_files[:10], val_transform, withMask = True, nsubs = nsubs, slice_nr = slice_nr)

# %% [markdown]
# ### Calculate test score from inference

# %%
def filterfromInference(tlearn, test_files, val_transform):
    test_ds = []
    test_loader = []

    #test_ds = myCacheDataset(data=test_files, transform=val_transform, cache_rate=1.0, num_workers=0)
    #test_ds = monai.data.Dataset(data=test_files, transform=val_transform)
    test_ds = maiDataset(data=test_files, transform=val_transform)
    test_loader= faiDataLoader(test_ds, batch_size=1, shuffle=False, num_workers=0)
        
        
    image, label = (0,1) if isinstance(test_ds[0], tuple) else (list(test_ds[0].keys())[0],list(test_ds[0].keys())[1])
#     subs = torch.randint(0, len(test_ds), (nsubs,))
#     nclass = test_ds[0][label].shape[0]
#     nchannels = test_ds[0][image].shape[0]
    
    pred, targ = tlearn.get_preds(dl=test_loader)
    breakpoint()
    value1 = compute_meandice(y_pred=pred, y=targ, include_background=False, to_onehot_y=True, mutually_exclusive=True)
    vindx = value1>=0.80
    vindx = vindx.squeeze(dim = 1)
    return value1, vindx

# %%
testDiceValue, testDFIndx = filterfromInference(learn, test_files, val_transform)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~/anaconda3/envs/fastai2/lib/python3.7/site-packages/fastai/learner.py in _with_events(self, f, event_type, ex, final)
#     154     def _with_events(self, f, event_type, ex, final=noop):
# --> 155         try:       self(f'before_{event_type}')       ;f()
#     156         except ex: self(f'after_cancel_{event_type}')
#
# ~/anaconda3/envs/fastai2/lib/python3.7/site-packages/fastai/learner.py in _do_one_batch(self)
#     163     def _do_one_batch(self):
# --> 164         self.pred = self.model(*self.xb)
#     165         self('after_pred')
#
# ~/anaconda3/envs/fastai2/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#
# ...

# %%
testDiceValue.mean()
# Out:
# tensor(0.9788)

# %%
def saveSampleInference(tlearn, test_files, val_transform, withMask = True, nsubs = 2, savedir = os.getcwd()):
    
    test_ds = []
    test_loader = []
    if withMask:
        test_ds = maiDataset(data=test_files, transform=val_transform)
        #test_ds = monai.data.Dataset(data=test_files, transform=val_transform)
        test_loader= faiDataLoader(test_ds, batch_size=1, shuffle=False, num_workers=0)
        
    else:
        fakeim, fakeseg = create_test_image_3d(256, 256, 256)
        n = nib.Nifti1Image(fakeseg, np.eye(4))
        nib.save(n, os.path.join(savedir, "segfake1.nii.gz"))
        #nib.load(os.path.join(os.getcwd(), f"segfake1.nii.gz"))
        labelpath = len(test_files)*[os.path.join(savedir, "segfake1.nii.gz")]
        
        test_files = [{'image':image, 'label': label} for image, label in zip(test_files, labelpath)]
        #print(test_files)
        #test_ds = myCacheDataset(data=test_files, transform=val_transform, cache_rate=1.0, num_workers=0)
        test_ds = maiDataset(data=test_files, transform=val_transform)
        #test_ds = monai.data.Dataset(data=test_files, transform=val_transform)
        test_loader= faiDataLoader(test_ds, batch_size=5, shuffle=False, num_workers=0)
        
    
    
    image, label = (0,1) if isinstance(test_ds[0], tuple) else (list(test_ds[0].keys())[0],list(test_ds[0].keys())[1])
    subs = torch.randint(0, len(test_ds), (nsubs,))
    nclass = test_ds[0][label].shape[0]
    nchannels = test_ds[0][image].shape[0]

    pred, targ = tlearn.get_preds(dl=test_loader)
    
    
    for iSub in subs:
        
        inImagefile = test_files[iSub]['image']
        inLabelfile = test_files[iSub]['label']
        #getImgSize = nib.load(inLabelfile).get_fdata().shape
        getImgObj = nib.load(inLabelfile)
        getImgSize = getImgObj.get_fdata().shape
        getImgAffine = getImgObj.affine
       
        outTensor = (pred[iSub, 0:1, :, :, :].sigmoid() <= 0.5).float().detach().cpu()   ### O for mask region, other channel is background, avoided
        outTensor = outTensor.numpy()
        doresize = monai.transforms.Resize(getImgSize, mode=('nearest'))
        outTensor = doresize (outTensor)
        outTensor = np.squeeze(outTensor, axis = 0)
        outLabelImage = nib.Nifti1Image(outTensor, np.eye(4))
        
        
        
        try:
            dest = shutil.copy(inImagefile, savedir)
            print("File copied successfully.") 
        # If source and destination are same 
        except shutil.SameFileError: 
            
            print("Source and destination represents the same file.") 
         
        
        try:
            dest = shutil.copy(inLabelfile, savedir)
            print("File copied successfully.") 
        # If source and destination are same 
        except shutil.SameFileError: 
            
            print("Source and destination represents the same file.") 
            

        nib.save(outLabelImage, f"{savedir}/predict_{os.path.basename(inLabelfile)}")

# %%
testfilesSel= test_files[:30]
savedir = f'{os.getcwd()}/InferenceFiles'
nsubs = 8
saveSampleInference(learn, testfilesSel, val_transform, withMask = True, nsubs = nsubs, savedir = savedir)
# Out:
# File copied successfully.
# File copied successfully.
# File copied successfully.
# File copied successfully.
# File copied successfully.
# File copied successfully.
# File copied successfully.
# File copied successfully.
# File copied successfully.
# File copied successfully.
# File copied successfully.
# File copied successfully.
# File copied successfully.
# File copied successfully.
# File copied successfully.
# File copied successfully.
